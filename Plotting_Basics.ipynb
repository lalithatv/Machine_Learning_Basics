# %% [markdown]
# <a href="https://colab.research.google.com/github/lalithatv/Machine_Learning_Basics/blob/master/Plotting_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://gist.github.com/curran/a08a1080b88344b0c8a7
# Out:
# Cloning into 'a08a1080b88344b0c8a7'...
# remote: Enumerating objects: 35, done.
# remote: Total 35 (delta 0), reused 0 (delta 0), pack-reused 35
# Unpacking objects: 100% (35/35), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Creating random numbers**

# %%
x = np.random.random((10,1))
print(x)
# Out:
# [[0.60797215]
#  [0.40824247]
#  [0.46884476]
#  [0.15836771]
#  [0.7257383 ]
#  [0.2484442 ]
#  [0.9169145 ]
#  [0.40724337]
#  [0.45246265]
#  [0.3032329 ]]

# %%
plt.plot(x,'*-')
plt.show()

# %%
x = np.linspace(0,100,50)
y = np.power(x,0.5)
plt.plot(x,y,'+-')
plt.show()

# %%
sns.set()
sns.lineplot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Plotting from dataset**

# %% [markdown]
# **Using External dataset**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
# drive  iris.csv  mobile_cleaned.csv  sample_data

# %%
data = pd.read_csv('mobile_cleaned.csv')
data.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
ax = sns.scatterplot( x = "stand_by_time" , y = "battery_capacity" , data=data )
plt.show()

# %%
ax = sns.scatterplot( x = "stand_by_time" , y = "battery_capacity" , hue = "thickness" , data=data )
plt.show()

# %%
ax = sns.distplot(data["stand_by_time"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.boxplot( x= "is_liked" , y = "battery_capacity", data=data )
plt.show()

# %%
ax = sns.boxplot( x= "expandable_memory" , y = "price", data=data )
plt.show()

# %% [markdown]
# **4 Axis to the maximum**

# %%
dataframe = pd.read_csv("/content/iris.csv")
print(dataframe.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
ax = sns.scatterplot( x = "petal.length" , y = "petal.width" , hue= "variety" , size = "sepal.width", data = dataframe )
plt.show()
